# %%
# 1. Creating a Module: mymodule.py
# ------------------------------
# %%writefile mymodule.py
def welcome(name):
    return f"Welcome, {name}!"
python
Copy code
# ------------------------------
# 2. Importing the Module
# ------------------------------
import mymodule
print("--- Module Output ---")
print(mymodule.welcome("Alice"))
python
Copy code
# ------------------------------
# 3. Creating a Package: mypackage
# ------------------------------
# !mkdir -p mypackage
python
Copy code
# __init__.py for the package
# %%writefile mypackage/__init__.py
# This makes 'mypackage' a package
python
Copy code
# greet.py inside package
# %%writefile mypackage/greet.py
def say_hello(name):
    return f"Hello, {name}!"
python
Copy code
# mathops.py inside package
# %%writefile mypackage/mathops.py
def multiply(a, b):
    return a * b
python
Copy code
# ------------------------------
# 4. Importing from the Package
# ------------------------------
from mypackage import greet, mathops

print("\n--- Package Output ---")
print(greet.say_hello("Charlie"))
print("Multiplication Result:", mathops.multiply(4, 5))
import re

text = "Email: alice123@example.com, Contact: +91-9876543210, DOB: 12-05-2000"

# 1. re.match - checks from the beginning of string
print("=== re.match ===")
match = re.match(r"Email", text)
if match:
    print("Match found at beginning:", match.group())
else:
    print("No match at beginning")

# 2. re.search - searches anywhere in the string
print("\n=== re.search ===")
search = re.search(r"\d{2}-\d{2}-\d{4}", text)
if search:
    print("Date found:", search.group())

# 3. re.findall - finds all matches
print("\n=== re.findall ===")
emails = re.findall(r"\S+@\S+\.\S+", text)
phones = re.findall(r"\+91-\d{10}", text)
print("Emails found:", emails)
print("Phone numbers found:", phones)

# 4. re.sub - substitute (replace) matched text
print("\n=== re.sub ===")
cleaned_text = re.sub(r"\d{2}-\d{2}-\d{4}", "[REDACTED-DATE]", text)
print("Text after removing date:", cleaned_text)

# Write to file
with open("demo.txt", "w") as f:
    f.write("Welcome to File I/O")

# Read from file
with open("demo.txt", "r") as f:
    data = f.read()
    print(data)

def count_up():
    for i in range(3):
        yield i

for number in count_up():
    print(number)

class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(self.name, "makes a sound")

class Dog(Animal):
    def speak(self):
        print(self.name, "barks")

d = Dog("Tommy")
d.speak()

count = 0

while count < 3:
    print("Count is", count)
    count += 1

for i in range(1, 6):
    print("Number:", i)

def multiply(x, y):
    result = x * y
    return result

print(multiply(4, 5))

coordinates = (10, 20, 30)

print("X:", coordinates[0])
print("Y:", coordinates[1])
print("Z:", coordinates[2])

person = {
    "name": "Alice",
    "age": 25,
    "city": "London"
}

print(person["name"])
person["age"] = 26
print(person)
